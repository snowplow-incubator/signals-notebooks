# %% [markdown]
# ## Test for interventions

# %%
from snowplow_signals import Signals
from dotenv import load_dotenv
import os

load_dotenv()

sp_signals = Signals(
    api_url=os.environ["SP_API_URL"],
    api_key=os.environ["SP_API_KEY"],
    api_key_id=os.environ["SP_API_KEY_ID"],
    org_id=os.environ["SP_ORG_ID"],
)

# %% [markdown]
# ### Define a new attribute
#
# This block creates a single feature definition including the logic how it should be calculated (it's filters and aggregation).
#
# The feature calculates the number of add to cart ecommerce events.

# %%
from snowplow_signals import (
    Attribute,
    Event,
)

count_page_views = Attribute(
    name="count_page_views",
    type="int32",
    events=[
        Event(name="page_view")
    ],
    aggregation="counter",
)

last_page_title = Attribute(
    name="last_page_title",
    type="string",
    events=[
        Event(name="page_view")
    ],
    aggregation="last",
    property="unstruct_event_com_hello_fresh_explib_decide_2:experiment_key",
)

# %% [markdown]
# ### Wrapping the attribute in a view
#
# All features need to be included in feature views that can be considered as "tables" of features.
#
# Feature views are immutable and versioned.

# %%
from snowplow_signals import View, LinkEntity

view = View(
    name="page_view_attributes",
    version=1,
    entity=LinkEntity(name="domain_userid"),
    attributes=[
        count_page_views,
    ],
    owner="user@company.com",
)

# %% [markdown]
# ### Testing the view
#
# Execute the feature view on the last one hour of data from the atomic events table to verify that it works correctly.

# %%
data = sp_signals.test(
    view=view,
    app_ids=["website"],
)
data
# Out:
#                           domain_userid  count_page_views
# 0  5de568e2-2b3c-41e1-a207-b2093896d274                 1
# 1  8d572123-c176-43b7-90a2-3401e868faa8                 1
# 2  d0709483-40a7-41cd-b21b-b93dc14fb9df                 1
# 3  4bf3b7f2-049d-47be-9edc-aa6183a2b769                 0
# 4  a5ba78d3-2d34-4eae-8715-a4d287a7d976                 1
# 5  fc46fd44-adb5-4ece-98ba-c2efa7e16d3d                 2
# 6  9cc599a1-2355-49e4-ad47-836e68c2ca15                 1
# 7  a6a7f83a-baea-4753-9b17-e18a9d7e7df1                 1
# 8  2315b033-e166-4094-ad38-43c73f15ba7d                 2
# 9  02f19737-7b38-40d5-9e16-392417788516                 2

# %%
from snowplow_signals import (
    RuleIntervention,
    InterventionSetAttributeContext,
    InterventionCriterion,
)

intervention = RuleIntervention(
    name="page_view_count",
    description="Resets the number of add_to_cart events when it becomes more than three.",
    method="set_attribute",
    context=InterventionSetAttributeContext(
        attribute="page_view_attributes:count_page_views",
        value=3,
        clear_history=True,
    ),
    criteria=InterventionCriterion(
        attribute="page_view_attributes:count_page_views",
        operator=">",
        value=3,
    ),
)

# %% [markdown]
# ### Define new intervention
#
# TODO: Shouldn't this be a part of the `apply()` function below?

# %%
sp_signals.interventions.create(intervention)
# Out:
# RuleInterventionOutput(name='page_view_count', version=1, method='set_attribute', target_agents=None, script_uri=None, context=SetAttributeContext(field_attributes=None, attribute='page_view_attributes:count_page_views', value=3, path=None, clear_history=True), description='Resets the number of add_to_cart events when it becomes more than three.', tags=None, owner=None, criteria=SignalsApiModelsInterventionCriterionCriterion(attribute='page_view_attributes:count_page_views', operator='>', value=3))

# %% [markdown]
# ### Applying the view to Signals
#
# The following block pushes the view definition to the Signals API and makes it available for processing.

# %%
applied = sp_signals.apply([view])
print(f"{len(applied)} objects applied")
# Out:
# 1 objects applied

# %% [markdown]
# ### Retrieving interventions
#
# TODO: We need a better flow for testing interventions by users.

# %%
import requests
import sseclient
import os
import json

API_URL = f"{os.environ["SP_API_URL"]}/api/v1/interventions"

headers = {
    "Accept": "text/event-stream",
}

params = {
    "domain_userid": "26e2769d-ee31-43d5-970d-bfa598c4f88e"
}

with requests.get(API_URL, headers=headers, params=params, stream=True) as response:
    if response.status_code != 200:
        print(f"Error: {response.status_code} {response.reason}")
    else:
        client = sseclient.SSEClient(response)
        for event in client.events():
            print(json.dumps(json.loads(event.data), indent=2))
# Out:
# {
#   "method": "set_attribute",
#   "target_agents": null,
#   "script_uri": null,
#   "context": {
#     "$attributes": {
#       "JM_test_view_1_stream:pv_count": 6,
#       "JM_test_view_1_stream:recent_view": "2025-05-26T14:33:45.405Z",
#       "demo_landing_page_1747756785_stream:latest_app_id": "website",
#       "demo_landing_page_1747756785_stream:latest_device_class": "Desktop",
#       "demo_landing_page_1747756785_stream:num_apps_l30d": [
#         "website"
#       ],
#       "demo_landing_page_1747756785_stream:num_apps_l7d": [
#         "website"
#       ],
#       "demo_landing_page_1747756785_stream:num_page_pings_l30d": 3,
#       "demo_landing_page_1747756785_stream:num_page_pings_l7d": 3,
#       "demo_landing_page_1747756785_stream:num_page_views_l30d": 6,
#       "demo_landing_page_1747756785_stream:num_page_views_l7d": 6,
#       "demo_landing_page_1747756785_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "demo_landing_page_1747756785_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "ilias_user_features_1_stream:page_view_count_last_7_days": 6,
#       "ilias_user_featuress_1_stream:page_view_count_last_7_days": 6,
#       "media_demo_view_1_stream:page_view_count": 6,
#       "new_user_features_v1_1_stream:page_view_count_last_7_days": 6,
#       "page_view_attributes_1_stream:count_page_views": 3,
#       "snowplow_website_demo_1_stream:latest_app_id": "website",
#       "snowplow_website_demo_1_stream:latest_device_class": "Desktop",
#       "snowplow_website_demo_1_stream:num_apps_l30d": [
#         "website"
#       ],
#       "snowplow_website_demo_1_stream:num_apps_l7d": [
#         "website"
#       ],
#       "snowplow_website_demo_1_stream:num_page_pings_l30d": 3,
#       "snowplow_website_demo_1_stream:num_page_pings_l7d": 3,
#       "snowplow_website_demo_1_stream:num_page_views_l30d": 6,
#       "snowplow_website_demo_1_stream:num_page_views_l7d": 6,
#       "snowplow_website_demo_1_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "snowplow_website_demo_1_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "test_domain_userid_features_1_stream:page_view_count_last_7_days": 6,
#       "website_view_1746192974625_stream:latest_app_id": "website",
#       "website_view_1746192974625_stream:latest_device_class": "Desktop",
#       "website_view_1746192974625_stream:num_apps_l30d": [
#         "website"
#       ],
#       "website_view_1746192974625_stream:num_apps_l7d": [
#         "website"
#       ],
#       "website_view_1746192974625_stream:num_page_pings_l30d": 3,
#       "website_view_1746192974625_stream:num_page_pings_l7d": 3,
#       "website_view_1746192974625_stream:num_page_views_l30d": 6,
#       "website_view_1746192974625_stream:num_page_views_l7d": 6,
#       "website_view_1746192974625_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "website_view_1746192974625_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "website_view_endtoend_1748195942713_stream:num_page_views_l7d": 6,
#       "website_view_endtoend_1748195942714_stream:num_page_views_l7d": 6
#     },
#     "attribute": "page_view_attributes:count_page_views",
#     "value": 3,
#     "clear_history": true
#   },
#   "intervention_id": "47e136be-f732-4e2a-9da5-cb42fdb9fc51",
#   "name": "page_view_count",
#   "version": 1
# }
# {
#   "method": "set_attribute",
#   "target_agents": null,
#   "script_uri": null,
#   "context": {
#     "$attributes": {
#       "JM_test_view_1_stream:pv_count": 7,
#       "JM_test_view_1_stream:recent_view": "2025-05-26T14:33:51.143Z",
#       "demo_landing_page_1747756785_stream:latest_app_id": "website",
#       "demo_landing_page_1747756785_stream:latest_device_class": "Desktop",
#       "demo_landing_page_1747756785_stream:num_apps_l30d": [
#         "website"
#       ],
#       "demo_landing_page_1747756785_stream:num_apps_l7d": [
#         "website"
#       ],
#       "demo_landing_page_1747756785_stream:num_page_pings_l30d": 3,
#       "demo_landing_page_1747756785_stream:num_page_pings_l7d": 3,
#       "demo_landing_page_1747756785_stream:num_page_views_l30d": 7,
#       "demo_landing_page_1747756785_stream:num_page_views_l7d": 7,
#       "demo_landing_page_1747756785_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "demo_landing_page_1747756785_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "ilias_user_features_1_stream:page_view_count_last_7_days": 7,
#       "ilias_user_featuress_1_stream:page_view_count_last_7_days": 7,
#       "media_demo_view_1_stream:page_view_count": 7,
#       "new_user_features_v1_1_stream:page_view_count_last_7_days": 7,
#       "page_view_attributes_1_stream:count_page_views": 3,
#       "snowplow_website_demo_1_stream:latest_app_id": "website",
#       "snowplow_website_demo_1_stream:latest_device_class": "Desktop",
#       "snowplow_website_demo_1_stream:num_apps_l30d": [
#         "website"
#       ],
#       "snowplow_website_demo_1_stream:num_apps_l7d": [
#         "website"
#       ],
#       "snowplow_website_demo_1_stream:num_page_pings_l30d": 3,
#       "snowplow_website_demo_1_stream:num_page_pings_l7d": 3,
#       "snowplow_website_demo_1_stream:num_page_views_l30d": 7,
#       "snowplow_website_demo_1_stream:num_page_views_l7d": 7,
#       "snowplow_website_demo_1_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "snowplow_website_demo_1_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "test_domain_userid_features_1_stream:page_view_count_last_7_days": 7,
#       "website_view_1746192974625_stream:latest_app_id": "website",
#       "website_view_1746192974625_stream:latest_device_class": "Desktop",
#       "website_view_1746192974625_stream:num_apps_l30d": [
#         "website"
#       ],
#       "website_view_1746192974625_stream:num_apps_l7d": [
#         "website"
#       ],
#       "website_view_1746192974625_stream:num_page_pings_l30d": 3,
#       "website_view_1746192974625_stream:num_page_pings_l7d": 3,
#       "website_view_1746192974625_stream:num_page_views_l30d": 7,
#       "website_view_1746192974625_stream:num_page_views_l7d": 7,
#       "website_view_1746192974625_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "website_view_1746192974625_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "website_view_endtoend_1748195942713_stream:num_page_views_l7d": 7,
#       "website_view_endtoend_1748195942714_stream:num_page_views_l7d": 7
#     },
#     "attribute": "page_view_attributes:count_page_views",
#     "value": 3,
#     "clear_history": true
#   },
#   "intervention_id": "c57f7ec2-d58e-4295-a029-68409eac13e1",
#   "name": "page_view_count",
#   "version": 1
# }
# {
#   "method": "set_attribute",
#   "target_agents": null,
#   "script_uri": null,
#   "context": {
#     "$attributes": {
#       "JM_test_view_1_stream:pv_count": 8,
#       "JM_test_view_1_stream:recent_view": "2025-05-26T14:34:09.078Z",
#       "demo_landing_page_1747756785_stream:latest_app_id": "website",
#       "demo_landing_page_1747756785_stream:latest_device_class": "Desktop",
#       "demo_landing_page_1747756785_stream:num_apps_l30d": [
#         "website"
#       ],
#       "demo_landing_page_1747756785_stream:num_apps_l7d": [
#         "website"
#       ],
#       "demo_landing_page_1747756785_stream:num_page_pings_l30d": 3,
#       "demo_landing_page_1747756785_stream:num_page_pings_l7d": 3,
#       "demo_landing_page_1747756785_stream:num_page_views_l30d": 8,
#       "demo_landing_page_1747756785_stream:num_page_views_l7d": 8,
#       "demo_landing_page_1747756785_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "demo_landing_page_1747756785_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "ilias_user_features_1_stream:page_view_count_last_7_days": 8,
#       "ilias_user_featuress_1_stream:page_view_count_last_7_days": 8,
#       "media_demo_view_1_stream:page_view_count": 8,
#       "new_user_features_v1_1_stream:page_view_count_last_7_days": 8,
#       "page_view_attributes_1_stream:count_page_views": 3,
#       "snowplow_website_demo_1_stream:latest_app_id": "website",
#       "snowplow_website_demo_1_stream:latest_device_class": "Desktop",
#       "snowplow_website_demo_1_stream:num_apps_l30d": [
#         "website"
#       ],
#       "snowplow_website_demo_1_stream:num_apps_l7d": [
#         "website"
#       ],
#       "snowplow_website_demo_1_stream:num_page_pings_l30d": 3,
#       "snowplow_website_demo_1_stream:num_page_pings_l7d": 3,
#       "snowplow_website_demo_1_stream:num_page_views_l30d": 8,
#       "snowplow_website_demo_1_stream:num_page_views_l7d": 8,
#       "snowplow_website_demo_1_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "snowplow_website_demo_1_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "test_domain_userid_features_1_stream:page_view_count_last_7_days": 8,
#       "website_view_1746192974625_stream:latest_app_id": "website",
#       "website_view_1746192974625_stream:latest_device_class": "Desktop",
#       "website_view_1746192974625_stream:num_apps_l30d": [
#         "website"
#       ],
#       "website_view_1746192974625_stream:num_apps_l7d": [
#         "website"
#       ],
#       "website_view_1746192974625_stream:num_page_pings_l30d": 3,
#       "website_view_1746192974625_stream:num_page_pings_l7d": 3,
#       "website_view_1746192974625_stream:num_page_views_l30d": 8,
#       "website_view_1746192974625_stream:num_page_views_l7d": 8,
#       "website_view_1746192974625_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "website_view_1746192974625_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "website_view_endtoend_1748195942713_stream:num_page_views_l7d": 8,
#       "website_view_endtoend_1748195942714_stream:num_page_views_l7d": 8
#     },
#     "attribute": "page_view_attributes:count_page_views",
#     "value": 3,
#     "clear_history": true
#   },
#   "intervention_id": "479f59cc-af02-497a-b7e0-a6365ee75bf0",
#   "name": "page_view_count",
#   "version": 1
# }
# {
#   "method": "set_attribute",
#   "target_agents": null,
#   "script_uri": null,
#   "context": {
#     "$attributes": {
#       "JM_test_view_1_stream:pv_count": 9,
#       "JM_test_view_1_stream:recent_view": "2025-05-26T14:34:22.484Z",
#       "demo_landing_page_1747756785_stream:latest_app_id": "website",
#       "demo_landing_page_1747756785_stream:latest_device_class": "Desktop",
#       "demo_landing_page_1747756785_stream:num_apps_l30d": [
#         "website"
#       ],
#       "demo_landing_page_1747756785_stream:num_apps_l7d": [
#         "website"
#       ],
#       "demo_landing_page_1747756785_stream:num_page_pings_l30d": 3,
#       "demo_landing_page_1747756785_stream:num_page_pings_l7d": 3,
#       "demo_landing_page_1747756785_stream:num_page_views_l30d": 9,
#       "demo_landing_page_1747756785_stream:num_page_views_l7d": 9,
#       "demo_landing_page_1747756785_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "demo_landing_page_1747756785_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "ilias_user_features_1_stream:page_view_count_last_7_days": 9,
#       "ilias_user_featuress_1_stream:page_view_count_last_7_days": 9,
#       "media_demo_view_1_stream:page_view_count": 9,
#       "new_user_features_v1_1_stream:page_view_count_last_7_days": 9,
#       "page_view_attributes_1_stream:count_page_views": 3,
#       "snowplow_website_demo_1_stream:latest_app_id": "website",
#       "snowplow_website_demo_1_stream:latest_device_class": "Desktop",
#       "snowplow_website_demo_1_stream:num_apps_l30d": [
#         "website"
#       ],
#       "snowplow_website_demo_1_stream:num_apps_l7d": [
#         "website"
#       ],
#       "snowplow_website_demo_1_stream:num_page_pings_l30d": 3,
#       "snowplow_website_demo_1_stream:num_page_pings_l7d": 3,
#       "snowplow_website_demo_1_stream:num_page_views_l30d": 9,
#       "snowplow_website_demo_1_stream:num_page_views_l7d": 9,
#       "snowplow_website_demo_1_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "snowplow_website_demo_1_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "test_domain_userid_features_1_stream:page_view_count_last_7_days": 9,
#       "website_view_1746192974625_stream:latest_app_id": "website",
#       "website_view_1746192974625_stream:latest_device_class": "Desktop",
#       "website_view_1746192974625_stream:num_apps_l30d": [
#         "website"
#       ],
#       "website_view_1746192974625_stream:num_apps_l7d": [
#         "website"
#       ],
#       "website_view_1746192974625_stream:num_page_pings_l30d": 3,
#       "website_view_1746192974625_stream:num_page_pings_l7d": 3,
#       "website_view_1746192974625_stream:num_page_views_l30d": 9,
#       "website_view_1746192974625_stream:num_page_views_l7d": 9,
#       "website_view_1746192974625_stream:num_sessions_l30d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "website_view_1746192974625_stream:num_sessions_l7d": [
#         "1a89bf27-ac1f-4e7f-af64-3efca196c0e8"
#       ],
#       "website_view_endtoend_1748195942713_stream:num_page_views_l7d": 9,
#       "website_view_endtoend_1748195942714_stream:num_page_views_l7d": 9
#     },
#     "attribute": "page_view_attributes:count_page_views",
#     "value": 3,
#     "clear_history": true
#   },
#   "intervention_id": "ecc6e396-4c75-489e-b578-5a291bf9bb19",
#   "name": "page_view_count",
#   "version": 1
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 21
#      19 else:
#      20     client = sseclient.SSEClient(response)
# ---> 21     for event in client.events():
#      22         print(json.dumps(json.loads(event.data), indent=2))
#
# File ~/Library/Caches/pypoetry/virtualenvs/signals-notebooks-CrNlc6H1-py3.12/lib/python3.12/site-packages/sseclient/__init__.py:55, in SSEClient.events(self)
#      54 def events(self):
# ---> 55     for chunk in self._read():
#      56         event = Event()
#      57         # Split before decoding so splitlines() only uses \r and \n
#
# File ~/Library/Caches/pypoetry/virtualenvs/signals-notebooks-CrNlc6H1-py3.12/lib/python3.12/site-packages/sseclient/__init__.py:45, in SSEClient._read(self)
#      38 """Read the incoming event source stream and yield event chunks.
#      39
#      40 Unfortunately it is possible for some servers to decide to break an
#      41 event into multiple HTTP chunks in the response. It is thus necessary
#      42 to correctly stitch together consecutive response chunks and find the
#      43 SSE delimiter (empty new line) to yield full, correct event chunks."""
#      44 data = b''
# ---> 45 for chunk in self._event_source:
#      46     for line in chunk.splitlines(True):
#      47         data += line
#
# File ~/Library/Caches/pypoetry/virtualenvs/signals-notebooks-CrNlc6H1-py3.12/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/Library/Caches/pypoetry/virtualenvs/signals-notebooks-CrNlc6H1-py3.12/lib/python3.12/site-packages/urllib3/response.py:1063, in HTTPResponse.stream(self, amt, decode_content)
#    1047 """
#    1048 A generator wrapper for the read() method. A call will block until
#    1049 ``amt`` bytes have been read from the connection or until the
#    (...)   1060     'content-encoding' header.
#    1061 """
#    1062 if self.chunked and self.supports_chunked_reads():
# -> 1063     yield from self.read_chunked(amt, decode_content=decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/Library/Caches/pypoetry/virtualenvs/signals-notebooks-CrNlc6H1-py3.12/lib/python3.12/site-packages/urllib3/response.py:1219, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1216     amt = None
#    1218 while True:
# -> 1219     self._update_chunk_length()
#    1220     if self.chunk_left == 0:
#    1221         break
#
# File ~/Library/Caches/pypoetry/virtualenvs/signals-notebooks-CrNlc6H1-py3.12/lib/python3.12/site-packages/urllib3/response.py:1138, in HTTPResponse._update_chunk_length(self)
#    1136 if self.chunk_left is not None:
#    1137     return None
# -> 1138 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139 line = line.split(b";", 1)[0]
#    1140 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
